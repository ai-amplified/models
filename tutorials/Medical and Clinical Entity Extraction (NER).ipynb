# %% [markdown]
# # API Tutorial - Medical and Clinical Entity Extraction (NER)

# %% [markdown]
# ## Short Description:
# The Named Entity Recognition (NER) models for medical entity extraction developed by Aimped are cutting-edge tools designed to enhance the accuracy and efficiency of medical text analysis across various healthcare domains. These models leverage advanced machine learning techniques and are trained on custom datasets to meet the specific needs of healthcare professionals, researchers, and stakeholders.
#
# Some of the models include:
# - **Extract Posological Entities from Medical Texts:** This model specializes in identifying posological entities to improve patient report analysis.
# - **Extract Entities from Radiology Reports:** It analyzes radiology reports to identify 14 distinct entities such as procedures and imaging findings.
# - **Extract Cancer Genetics Information from Medical Texts:** This model uses BioBERT embeddings to identify 16 entities related to cancer genetics, including genes and proteins, achieving State-of-the-Art accuracy for biomedical research.
# - **Extract Clinical Entities from Medical Texts (Large):** This model identifies 60 entities, such as symptoms and vital signs, to aid in processing diagnoses and treatments.
#
# Together, these models significantly contribute to better patient care, streamlined research, and informed decision-making in the medical field.
#
# We also offer many more NER models for medical and healthcare applications designed to address specific needs within the healthcare industry, which you can explore. These include models like:
# - [Extract Problems, Treatments and Tests from Clinical Reports/Medical Texts](https://aimped.ai/models/extract-problems-treatments-and-tests-from-clinical-reports-medical-texts-221)
# - [Extract ADE and Drugs from Case Reports](https://aimped.ai/models/extract-ade-and-drugs-from-case-reports-209)
# - [Extract Molecular Mechanisms of Infection, Virulence, and Resistance from Medical Texts](https://aimped.ai/models/extract-molecular-mechanisms-of-infection-virulence,-and-resistance-from-medical-texts-220)
# - [Extract, Diagnosis and Procedures from Spanish Clinical Case Studies](https://aimped.ai/models/extract-diagnosis-and-procedures-from-spanish-clinical-case-studies-232)
# - [Extract Drug-Chemical Gene-Protein Entities](https://aimped.ai/models/extract-drug-chemical-gene-protein-entities-229)
# - [Extract Anatomical Structures from Medical Text](https://aimped.ai/models/extract-anatomical-structures-from-medical-text-230)
# - [Extract Diseases from Medical Texts](https://aimped.ai/models/extract-diseases-from-medical-texts-223)
# - [Extract 41 Entities from Medical Texts](https://aimped.ai/models/extract-41-entities-from-medical-texts-217)
# - [Extract Medical Entities to Figure Out the Genetic Underpinnings of Different Cancer Types](https://aimped.ai/models/extract-medical-entities-to-figure-out-the-genetic-underpinnings-of-different-cancer-types-214)
# - [Extract Chemical Entities from Medical Texts](https://aimped.ai/models/extract-chemical-entities-from-medical-texts-216)
# - [Extract Chemical and Disease Entities from Medical Text](https://aimped.ai/models/extract-chemical-and-disease-entities-from-medical-text-225)
# - [Extract Living Species from Medical Texts](https://aimped.ai/models/extract-living-species-from-medical-texts-226)
# - [Extract Chemicals and Genes with Normality Status from Texts of Clinical Research](https://aimped.ai/models/extract-chemicals-and-genes-with-normality-status-from-texts-of-clinical-research-228)
# - [Extract Biological Entities from Scientific Texts](https://aimped.ai/models/extract-biological-entities-from-scientific-texts-231)
# - [Extract Pharmacovigilance Entities from Medical Texts](https://aimped.ai/models/extract-pharmacovigilance-entities-from-medical-texts-219)
# - [Extract Biomedical Entities from Scientific Texts](https://aimped.ai/models/extract-biomedical-entities-from-scientific-texts-224)
#
#
#
# ## Tutorial
# This tutorial will guide you through using few of the Healthcare NER model's API. By following the steps below, you'll be able to extract the enities from medical text using the API. The main steps involved are:
#
# 1. Creating an access token
# 2. Installing the aimped library
# 3. Running the API with your credentials and payload

# %% [markdown]
# ## Step 1: Create Access Token

# %% [markdown]
# To use the API, you need an access token. Follow these steps to create one:
#
# 1. Go to the [API Access Token Creation Page](https://aimped.ai/a3m/#/tokens). You will land here:
# ![Token Creation Page](images/token_11.png)
#
# 2. Select scopes and click on "Create Token".
# 3. After clicking this button, you will see the pop-up from where you can copy the User Key and User Secret.
#
# ![Token Creation Page2](images/token_22.png)
#
# 3. Copy the generated access tokens and keep it safe. You'll need it for the next steps.

# %% [markdown]
# ## Step 2: Install aimped Library
# To interact with the API, you need to install the aimped Python library. Open your terminal or command prompt and run the following command:

# %%
# !pip install aimped==0.2.44 seqeval

# %% [markdown]
# This command will install the necessary library to communicate with the API.

# %% [markdown]
# ## Step 3: Run the API
# Now that you have your access tokens and the library installed, you can run the API to extract medical entities from text. Follow these steps:

# %% [markdown]
# ### Set up your credentials:

# %%
user_key = "YOUR_USER_KEY"
user_secret = "YOUR_USER_SECRET"

# %% [markdown]
# ### Import the AimpedAPI class and set the base URL

# %%
from aimped.services.api import AimpedAPI

BASE_URL = 'https://aimped.ai'

# %% [markdown]
# ### Initialize the API service:

# %%
api_service = AimpedAPI(user_key, user_secret, {"base_url": BASE_URL})

# %% [markdown]
# ### Define your payload:
# Define payload according to your input data type.

# %% [markdown]
# ### 1. Extract Posological Entities from Medical Texts

# %% [markdown]
# For using this model, you need to enter the correct **Model ID**. The Model ID can be found under "API Information" in the "API Details" tab on each model card.

# %%
model_id = "208" # the Model ID can be found under "API Information" in the "API Details" tab on each model card.

# %%
text = "A 42 year-old woman with type 1 diabetes for 22 years was married recently, and she and her husband have decided to have a child. Neither had children previously. The woman has hypertension treated with an angiotensin converting enzyme (ACE) inhibitor and a diuretic with maintenance of blood pressure at 120/80 mm Hg. Her insulin doses are all administered through a continuous insulin infusion pump using insulin aspart. Her present weight is 60 kg thus, her insulin requirement was calculated as 0.6 times her weight in kilograms = 36 units every day. She reported that she would try to become pregnant next month."

# %%
payload = {
    "data_type": "data_json",
    "data_json": {
        "text": [text],
        "entity": [
            "ADE",
            "Dosage",
            "Drug",
            "Duration",
            "Form",
            "Frequency",
            "Reason",
            "Route",
            "Strength"
        ],
        "model_name": "nlp-health-ner-posology-base-en"
    }
}

# %% [markdown]
# #### Run the model:

# %%
result = api_service.run_model(model_id, payload)

# %% [markdown]
# If you're running this model for the first time or after a long time, you might see the following message:

# %%
print(result)
# Out:
# {'message': 'We will notify you via email when the instance is ready.'}

# %% [markdown]
# Wait for the email notification indicating that the instance is ready. You will be notified on the [Aimped](https://aimped.ai/) as well.
# ![Notification Page](images/notif_1.png)
#
# You will see this notification, once the instance is ready:
# ![Notification Page2](images/ner_notif.png)

# %% [markdown]
# Once you receive the email or notification on aimped, run the model again:

# %%
result = api_service.run_model(model_id, payload)

# %%
result
# Out:
# {'used_credits': 3.45,
#  'status': True,
#  'data_type': ['data_json'],
#  'output': {'data_json': {'result': [[{'entity': 'Reason',
#       'confidence': 0.9998448689778646,
#       'chunk': 'diabetes mellitus type 2',
#       'begin': 118,
#       'end': 142},
#      {'entity': 'Drug',
#       'confidence': 0.9758263230323792,
#       'chunk': 'insulin',
#       'begin': 202,
#       'end': 209},
#      {'entity': 'Route',
#       'confidence': 0.9990241527557373,
#       'chunk': 'injections',
#       'begin': 210,
#       'end': 220},
#      {'entity': 'Drug',
#       'confidence': 0.9998527765274048,
#       'chunk': 'metformin',
#       'begin': 231,
#       'end': 240},
#      {'entity': 'Strength',
#       'confidence': 0.9998131394386292,
#       'chunk': '1000mg',
#       'begin': 241,
#       'end': 247},
#      {'entity': 'Frequency',
#       'confidence': 0.9997444748878479,
#       'chunk': 'daily',
#       'begin': 248,
#       'end': 253},
#      {'entity': 'Reason',
#       'confidence': 0.9478157043457032,
#       'chunk': 'to manage her blood sugar levels',
#       'begin': 254,
#       'end': 286}]]}}}

# %% [markdown]
# #### Visualize the result

# %%
from aimped.nlp.ner import NERVisualizer
viz = NERVisualizer()

# %%
result = result["output"]["data_json"]["result"][0]

# %%
viz.display_visualization(text, result)
# Out:
#         <style>
#         .non-ner {
#             color: black;
#             line-height: 2.2rem;
#             font-size: 1rem;
#         }
#         .entity-wrapper {
#             display: inline-flex;
#             justify-content: space-between;
#             text-align: center;
#             border-radius: 5px;
#             margin: 3px 2px;
#             border: 1px solid;
#             overflow: hidden;
#             font-size: 1rem;
#         }
#         .entity-name {
#             font-size: 0.9rem;
#             line-height: 1.5rem;
#             text-align: center;
#             font-weight: 400;
#             padding: 2px 5px;
#             display: inline-block;
#         }
#         .entity-type {
#             font-size: 0.9rem;
#             line-height: 1.5rem;
#             color: #fff;
#             text-transform: uppercase;
#             font-weight: 500;
#             display: inline-block;
#             padding: 2px 5px;
#         }
#         </style>
#         <div style="padding: 14px;"><div dir="auto"><span class="non-ner">A 42 year-old woman with type 1 diabetes for 22 years was married recently, and she and her husband have decided to ha</span>
#                 <span class="entity-wrapper" style="background-color: rgba(92, 92, 224, 0.12); border-color: #5C5CE0;">
#                     <span class="entity-name">diabetes mellitus type 2</span>
#                     <span class="entity-type" style="background-color: #5C5CE0;">Reason</span>
#                 </span>
#             <span class="non-ner">children previously. The woman has hypertension treated with</span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">insulin</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">Drug</span>
#                 </span>
#             <span class="non-ner">i</span>
#                 <span class="entity-wrapper" style="background-color: rgba(206, 39, 131, 0.12); border-color: #CE2783;">
#                     <span class="entity-name">injections</span>
#                     <span class="entity-type" style="background-color: #CE2783;">Route</span>
#                 </span>
#             <span class="non-ner">nverting en</span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">metformin</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">Drug</span>
#                 </span>
#             <span class="non-ner">)</span>
#                 <span class="entity-wrapper" style="background-color: rgba(210, 178, 0, 0.12); border-color: #D2B200;">
#                     <span class="entity-name">1000mg</span>
#                     <span class="entity-type" style="background-color: #D2B200;">Strength</span>
#                 </span>
#             <span class="non-ner">i</span>
#                 <span class="entity-wrapper" style="background-color: rgba(177, 48, 189, 0.12); border-color: #B130BD;">
#                     <span class="entity-name">daily</span>
#                     <span class="entity-type" style="background-color: #B130BD;">Frequency</span>
#                 </span>
#             <span class="non-ner">n</span>
#                 <span class="entity-wrapper" style="background-color: rgba(92, 92, 224, 0.12); border-color: #5C5CE0;">
#                     <span class="entity-name">to manage her blood sugar levels</span>
#                     <span class="entity-type" style="background-color: #5C5CE0;">Reason</span>
#                 </span>
#             <span class="non-ner"> blood pressure at 120/80 mm Hg. Her insulin doses are all administered through a continuous insulin infusion pump using insulin aspart. Her present weight is 60 kg thus, her insulin requirement was calculated as 0.6 times her weight in kilograms = 36 units every day. She reported that she would try to become pregnant next month.</span></div></div>

# %% [markdown]
# ### 2. Extract Entities from Radiology Reports

# %% [markdown]
# For using this model, you need to enter the correct **Model ID**. The Model ID can be found under "API Information" in the "API Details" tab on each model card.

# %%
model_id = "210" # the Model ID can be found under "API Information" in the "API Details" tab on each model card.

# %%
text = "A smaller enhancing extra-axial mass more suggestive of atypical meningioma is seen overlying the right mid temporal lobe measuring 1.3 x 0.6 CM. (Axial series 12 image 26).\nThere is no significant end vessel ischemic small vessel disease.\nThere is no acute infarct seen. No intracranial hemorrhage is recognized.\nThere is no parenchymal mass or mass effect.\nA developmental venous anomaly is suggested within the left parietal lobe.\nThe ventricles, sulci and basal cisterns appear unremarkable.\nThe vertebral and internal carotid arteries demonstrate expected flow voids indicating their patency.\nThe central skull base and temporal bones are intact. The calvarium appears unremarkable. The orbits are unremarkable.\nThe paranasal sinuses demonstrate mucosal thickening partially outlining anterior and posterior ethmoid air cells and the right and left antrum with a hyperplastic polypoid component along the floor. No air-fluid levels are noted."

# %%
payload = {
    "data_type": "data_json",
    "data_json": {
        "text": [text],
        "entity": [
            "procedure",
            "direction",
            "findings_imaging",
            "imaging_technique",
            "imaging_test",
            "measurements",
            "med_device",
            "part_body",
            "symptom",
            "syndrome_disorder_disease",
            "test",
            "test_result",
            "units",
            "findings_other"
        ],
        "model_name": "nlp-health-ner-radiology-base-en"
    }
}

# %% [markdown]
# #### Run the model:

# %%
result = api_service.run_model(model_id, payload)

# %%
result
# Out:
# {'used_credits': 9.47,
#  'status': True,
#  'data_type': ['data_json'],
#  'output': {'data_json': {'result': [[{'entity': 'part_body',
#       'confidence': 0.9913526177406311,
#       'chunk': 'extra-axial',
#       'begin': 20,
#       'end': 31},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9985692501068115,
#       'chunk': 'mass',
#       'begin': 32,
#       'end': 36},
#      {'entity': 'findings_imaging',
#       'confidence': 0.6215108633041382,
#       'chunk': 'atypical meningioma',
#       'begin': 56,
#       'end': 75},
#      {'entity': 'direction',
#       'confidence': 0.9824029207229614,
#       'chunk': 'right mid',
#       'begin': 98,
#       'end': 107},
#      {'entity': 'part_body',
#       'confidence': 0.9998378753662109,
#       'chunk': 'temporal lobe',
#       'begin': 108,
#       'end': 121},
#      {'entity': 'measurements',
#       'confidence': 0.9997573296229044,
#       'chunk': '1.3 x 0.6',
#       'begin': 132,
#       'end': 141},
#      {'entity': 'units',
#       'confidence': 0.8141154646873474,
#       'chunk': 'CM',
#       'begin': 142,
#       'end': 144},
#      {'entity': 'imaging_test',
#       'confidence': 0.800357460975647,
#       'chunk': 'Axial series',
#       'begin': 147,
#       'end': 159},
#      {'entity': 'measurements',
#       'confidence': 0.9770841002464294,
#       'chunk': '26',
#       'begin': 169,
#       'end': 171},
#      {'entity': 'findings_imaging',
#       'confidence': 0.8539599776268005,
#       'chunk': 'end vessel ischemic small vessel disease',
#       'begin': 198,
#       'end': 238},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9998888969421387,
#       'chunk': 'acute infarct',
#       'begin': 252,
#       'end': 265},
#      {'entity': 'part_body',
#       'confidence': 0.9994756579399109,
#       'chunk': 'intracranial',
#       'begin': 275,
#       'end': 287},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9869017004966736,
#       'chunk': 'hemorrhage',
#       'begin': 288,
#       'end': 298},
#      {'entity': 'part_body',
#       'confidence': 0.9999436140060425,
#       'chunk': 'parenchymal',
#       'begin': 326,
#       'end': 337},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9998774528503418,
#       'chunk': 'mass',
#       'begin': 338,
#       'end': 342},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9998612403869629,
#       'chunk': 'mass effect',
#       'begin': 346,
#       'end': 357},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9847246706485748,
#       'chunk': 'developmental venous anomaly',
#       'begin': 361,
#       'end': 389},
#      {'entity': 'direction',
#       'confidence': 0.9998441934585571,
#       'chunk': 'left',
#       'begin': 414,
#       'end': 418},
#      {'entity': 'part_body',
#       'confidence': 0.9998995065689087,
#       'chunk': 'parietal lobe',
#       'begin': 419,
#       'end': 432},
#      {'entity': 'part_body',
#       'confidence': 0.9998928308486938,
#       'chunk': 'ventricles',
#       'begin': 438,
#       'end': 448},
#      {'entity': 'part_body',
#       'confidence': 0.9985530972480774,
#       'chunk': 'sulci',
#       'begin': 450,
#       'end': 455},
#      {'entity': 'part_body',
#       'confidence': 0.9992504715919495,
#       'chunk': 'basal cisterns',
#       'begin': 460,
#       'end': 474},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9998107552528381,
#       'chunk': 'unremarkable',
#       'begin': 482,
#       'end': 494},
#      {'entity': 'part_body',
#       'confidence': 0.9999370574951172,
#       'chunk': 'vertebral',
#       'begin': 500,
#       'end': 509},
#      {'entity': 'part_body',
#       'confidence': 0.999687671661377,
#       'chunk': 'internal carotid arteries',
#       'begin': 514,
#       'end': 539},
#      {'entity': 'findings_imaging',
#       'confidence': 0.99916672706604,
#       'chunk': 'flow voids',
#       'begin': 561,
#       'end': 571},
#      {'entity': 'direction',
#       'confidence': 0.9995079040527344,
#       'chunk': 'central',
#       'begin': 602,
#       'end': 609},
#      {'entity': 'part_body',
#       'confidence': 0.9998730421066284,
#       'chunk': 'skull base',
#       'begin': 610,
#       'end': 620},
#      {'entity': 'part_body',
#       'confidence': 0.999885082244873,
#       'chunk': 'temporal bones',
#       'begin': 625,
#       'end': 639},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9988994598388672,
#       'chunk': 'intact',
#       'begin': 644,
#       'end': 650},
#      {'entity': 'part_body',
#       'confidence': 0.9998613595962524,
#       'chunk': 'calvarium',
#       'begin': 656,
#       'end': 665},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9993626475334167,
#       'chunk': 'unremarkable',
#       'begin': 674,
#       'end': 686},
#      {'entity': 'part_body',
#       'confidence': 0.9973933696746826,
#       'chunk': 'orbits',
#       'begin': 692,
#       'end': 698},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9988968372344971,
#       'chunk': 'unremarkable',
#       'begin': 703,
#       'end': 715},
#      {'entity': 'part_body',
#       'confidence': 0.9999113082885742,
#       'chunk': 'paranasal sinuses',
#       'begin': 721,
#       'end': 738},
#      {'entity': 'part_body',
#       'confidence': 0.9582757353782654,
#       'chunk': 'mucosal',
#       'begin': 751,
#       'end': 758},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9223150014877319,
#       'chunk': 'thickening',
#       'begin': 759,
#       'end': 769},
#      {'entity': 'part_body',
#       'confidence': 0.7830334901809692,
#       'chunk': 'anterior and',
#       'begin': 790,
#       'end': 802},
#      {'entity': 'direction',
#       'confidence': 0.781956136226654,
#       'chunk': 'posterior',
#       'begin': 803,
#       'end': 812},
#      {'entity': 'part_body',
#       'confidence': 0.6002486348152161,
#       'chunk': 'ethmoid',
#       'begin': 813,
#       'end': 820},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9520661234855652,
#       'chunk': 'air cells',
#       'begin': 821,
#       'end': 830},
#      {'entity': 'part_body',
#       'confidence': 0.9953457315762838,
#       'chunk': 'right and left antrum',
#       'begin': 839,
#       'end': 860},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9989073276519775,
#       'chunk': 'hyperplastic polypoid component',
#       'begin': 868,
#       'end': 899},
#      {'entity': 'findings_imaging',
#       'confidence': 0.9954150915145874,
#       'chunk': 'air-fluid levels',
#       'begin': 920,
#       'end': 936}]]}}}

# %% [markdown]
# #### Visualize the result

# %%
from aimped.nlp.ner import NERVisualizer
viz = NERVisualizer()

# %%
result = result["output"]["data_json"]["result"][0]

# %%
viz.display_visualization(text, result)
# Out:
#         <style>
#         .non-ner {
#             color: black;
#             line-height: 2.2rem;
#             font-size: 1rem;
#         }
#         .entity-wrapper {
#             display: inline-flex;
#             justify-content: space-between;
#             text-align: center;
#             border-radius: 5px;
#             margin: 3px 2px;
#             border: 1px solid;
#             overflow: hidden;
#             font-size: 1rem;
#         }
#         .entity-name {
#             font-size: 0.9rem;
#             line-height: 1.5rem;
#             text-align: center;
#             font-weight: 400;
#             padding: 2px 5px;
#             display: inline-block;
#         }
#         .entity-type {
#             font-size: 0.9rem;
#             line-height: 1.5rem;
#             color: #fff;
#             text-transform: uppercase;
#             font-weight: 500;
#             display: inline-block;
#             padding: 2px 5px;
#         }
#         </style>
#         <div style="padding: 14px;"><div dir="auto"><span class="non-ner">A smaller enhancing </span>
#                 <span class="entity-wrapper" style="background-color: rgba(92, 92, 224, 0.12); border-color: #5C5CE0;">
#                     <span class="entity-name">extra-axial</span>
#                     <span class="entity-type" style="background-color: #5C5CE0;">part_body</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">mass</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">findings_imaging</span>
#                 </span>
#             <span class="non-ner"> more suggestive of </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">atypical meningioma</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">findings_imaging</span>
#                 </span>
#             <span class="non-ner"> is seen overlying the </span>
#                 <span class="entity-wrapper" style="background-color: rgba(206, 39, 131, 0.12); border-color: #CE2783;">
#                     <span class="entity-name">right mid</span>
#                     <span class="entity-type" style="background-color: #CE2783;">direction</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(92, 92, 224, 0.12); border-color: #5C5CE0;">
#                     <span class="entity-name">temporal lobe</span>
#                     <span class="entity-type" style="background-color: #5C5CE0;">part_body</span>
#                 </span>
#             <span class="non-ner"> measuring </span>
#                 <span class="entity-wrapper" style="background-color: rgba(210, 178, 0, 0.12); border-color: #D2B200;">
#                     <span class="entity-name">1.3 x 0.6</span>
#                     <span class="entity-type" style="background-color: #D2B200;">measurements</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(177, 48, 189, 0.12); border-color: #B130BD;">
#                     <span class="entity-name">CM</span>
#                     <span class="entity-type" style="background-color: #B130BD;">units</span>
#                 </span>
#             <span class="non-ner">. (</span>
#                 <span class="entity-wrapper" style="background-color: rgba(22, 135, 140, 0.02); border-color: #16878C;">
#                     <span class="entity-name">Axial series</span>
#                     <span class="entity-type" style="background-color: #16878C;">imaging_test</span>
#                 </span>
#             <span class="non-ner"> 12 image </span>
#                 <span class="entity-wrapper" style="background-color: rgba(210, 178, 0, 0.12); border-color: #D2B200;">
#                     <span class="entity-name">26</span>
#                     <span class="entity-type" style="background-color: #D2B200;">measurements</span>
#                 </span>
#             <span class="non-ner">).
# There is no significant </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">end vessel ischemic small vessel disease</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">findings_imaging</span>
#                 </span>
#             <span class="non-ner">.
# There is no </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">acute infarct</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">findings_imaging</span>
#                 </span>
#             <span class="non-ner"> seen. No </span>
#                 <span class="entity-wrapper" style="background-color: rgba(92, 92, 224, 0.12); border-color: #5C5CE0;">
#                     <span class="entity-name">intracranial</span>
#                     <span class="entity-type" style="background-color: #5C5CE0;">part_body</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">hemorrhage</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">findings_imaging</span>
#                 </span>
#             <span class="non-ner"> is recognized.
# There is no </span>
#                 <span class="entity-wrapper" style="background-color: rgba(92, 92, 224, 0.12); border-color: #5C5CE0;">
#                     <span class="entity-name">parenchymal</span>
#                     <span class="entity-type" style="background-color: #5C5CE0;">part_body</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">mass</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">findings_imaging</span>
#                 </span>
#             <span class="non-ner"> or </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">mass effect</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">findings_imaging</span>
#                 </span>
#             <span class="non-ner">.
# A </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">developmental venous anomaly</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">findings_imaging</span>
#                 </span>
#             <span class="non-ner"> is suggested within the </span>
#                 <span class="entity-wrapper" style="background-color: rgba(206, 39, 131, 0.12); border-color: #CE2783;">
#                     <span class="entity-name">left</span>
#                     <span class="entity-type" style="background-color: #CE2783;">direction</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(92, 92, 224, 0.12); border-color: #5C5CE0;">
#                     <span class="entity-name">parietal lobe</span>
#                     <span class="entity-type" style="background-color: #5C5CE0;">part_body</span>
#                 </span>
#             <span class="non-ner">.
# The </span>
#                 <span class="entity-wrapper" style="background-co

# %% [markdown]
# ### 3. Extract Cancer Genetics Information from Medical Texts

# %% [markdown]
# For using this model, you need to enter the correct **Model ID**. The Model ID can be found under "API Information" in the "API Details" tab on each model card.

# %%
model_id = "272" # the Model ID can be found under "API Information" in the "API Details" tab on each model card.

# %%
text = "To elucidate the role of N-glycosylation in the functional activity of the universal glucose transporter, Glut-1, we investigated effects of the N-glycosylation inhibitor, tunicamycin, on glucose transport by human leukemic cell lines K562, U937 and HL60."

# %%
payload = {
    "data_type": "data_json",
    "data_json": {
        "text": [text],
        "entity": [
            "Organ",
            "Organism",
            "Organism_subdivision",
            "Organism_substance",
            "Amino_acid",
            "Anatomical_system",
            "Cancer",
            "Cell",
            "Cellular_component",
            "Developing_anatomical_structure",
            "Gene_or_gene_product",
            "Immaterial_anatomical_entity",
            "Multi_tissue_structure",
            "Pathological_formation",
            "Simple_chemical",
            "Tissue"
        ],
        "model_name": "nlp-health-ner-cancer-genetics-large-en"
    }
}

# %% [markdown]
# #### Run the model:

# %%
result = api_service.run_model(model_id, payload)

# %%
result
# Out:
# {'used_credits': 2.5500000000000003,
#  'status': True,
#  'data_type': ['data_json'],
#  'output': {'data_json': {'result': [[{'entity': 'Simple_chemical',
#       'confidence': 0.999813973903656,
#       'chunk': 'glucose',
#       'begin': 85,
#       'end': 92},
#      {'entity': 'Gene_or_gene_product',
#       'confidence': 0.999995231628418,
#       'chunk': 'Glut-1',
#       'begin': 106,
#       'end': 112},
#      {'entity': 'Simple_chemical',
#       'confidence': 0.9999864101409912,
#       'chunk': 'tunicamycin',
#       'begin': 172,
#       'end': 183},
#      {'entity': 'Simple_chemical',
#       'confidence': 0.9998974800109863,
#       'chunk': 'glucose',
#       'begin': 188,
#       'end': 195},
#      {'entity': 'Cell',
#       'confidence': 0.9999009370803833,
#       'chunk': 'leukemic cell lines K562',
#       'begin': 215,
#       'end': 239},
#      {'entity': 'Cell',
#       'confidence': 0.999951958656311,
#       'chunk': 'U937',
#       'begin': 241,
#       'end': 245},
#      {'entity': 'Cell',
#       'confidence': 0.999927282333374,
#       'chunk': 'HL60',
#       'begin': 250,
#       'end': 254}]]}}}

# %% [markdown]
# #### Visualize the result

# %%
from aimped.nlp.ner import NERVisualizer
viz = NERVisualizer()

# %%
result = result["output"]["data_json"]["result"][0]

# %%
viz.display_visualization(text, result)
# Out:
#         <style>
#         .non-ner {
#             color: black;
#             line-height: 2.2rem;
#             font-size: 1rem;
#         }
#         .entity-wrapper {
#             display: inline-flex;
#             justify-content: space-between;
#             text-align: center;
#             border-radius: 5px;
#             margin: 3px 2px;
#             border: 1px solid;
#             overflow: hidden;
#             font-size: 1rem;
#         }
#         .entity-name {
#             font-size: 0.9rem;
#             line-height: 1.5rem;
#             text-align: center;
#             font-weight: 400;
#             padding: 2px 5px;
#             display: inline-block;
#         }
#         .entity-type {
#             font-size: 0.9rem;
#             line-height: 1.5rem;
#             color: #fff;
#             text-transform: uppercase;
#             font-weight: 500;
#             display: inline-block;
#             padding: 2px 5px;
#         }
#         </style>
#         <div style="padding: 14px;"><div dir="auto"><span class="non-ner">To elucidate the role of N-glycosylation in the functional activity of the universal </span>
#                 <span class="entity-wrapper" style="background-color: rgba(92, 92, 224, 0.12); border-color: #5C5CE0;">
#                     <span class="entity-name">glucose</span>
#                     <span class="entity-type" style="background-color: #5C5CE0;">Simple_chemical</span>
#                 </span>
#             <span class="non-ner"> transporter, </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">Glut-1</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">Gene_or_gene_product</span>
#                 </span>
#             <span class="non-ner">, we investigated effects of the N-glycosylation inhibitor, </span>
#                 <span class="entity-wrapper" style="background-color: rgba(92, 92, 224, 0.12); border-color: #5C5CE0;">
#                     <span class="entity-name">tunicamycin</span>
#                     <span class="entity-type" style="background-color: #5C5CE0;">Simple_chemical</span>
#                 </span>
#             <span class="non-ner">, on </span>
#                 <span class="entity-wrapper" style="background-color: rgba(92, 92, 224, 0.12); border-color: #5C5CE0;">
#                     <span class="entity-name">glucose</span>
#                     <span class="entity-type" style="background-color: #5C5CE0;">Simple_chemical</span>
#                 </span>
#             <span class="non-ner"> transport by human </span>
#                 <span class="entity-wrapper" style="background-color: rgba(206, 39, 131, 0.12); border-color: #CE2783;">
#                     <span class="entity-name">leukemic cell lines K562</span>
#                     <span class="entity-type" style="background-color: #CE2783;">Cell</span>
#                 </span>
#             <span class="non-ner">, </span>
#                 <span class="entity-wrapper" style="background-color: rgba(206, 39, 131, 0.12); border-color: #CE2783;">
#                     <span class="entity-name">U937</span>
#                     <span class="entity-type" style="background-color: #CE2783;">Cell</span>
#                 </span>
#             <span class="non-ner"> and </span>
#                 <span class="entity-wrapper" style="background-color: rgba(206, 39, 131, 0.12); border-color: #CE2783;">
#                     <span class="entity-name">HL60</span>
#                     <span class="entity-type" style="background-color: #CE2783;">Cell</span>
#                 </span>
#             <span class="non-ner">.</span></div></div>

# %% [markdown]
# ### 4. Extract Clinical Entities from Medical Texts (Large)

# %% [markdown]
# For using this model, you need to enter the correct **Model ID**. The Model ID can be found under "API Information" in the "API Details" tab on each model card.

# %%
model_id = "218" # the Model ID can be found under "API Information" in the "API Details" tab on each model card.

# %%
text = "A 42-year-old woman with type 1 diabetes for 22 years was married recently, and she and her husband have decided to have a child. Neither had children previously. The woman has hypertension treated with an angiotensin-converting enzyme (ACE) inhibitor and a diuretic to maintain blood pressure at 120/80 mm Hg. Her glycated hemoglobin (HbA1c) is 6.7% (normal, <5.7%). Her insulin doses are all administered through a continuous insulin infusion pump using insulin aspart. Her present weight is 60 kgÍ¾ thus, her insulin requirement was calculated as 0.6 times her weight in kilograms = 36 units daily. She reported that she would try to become pregnant next month."

# %%
payload = {
    "data_type": "data_json",
    "data_json": {
        "text": [text],
        "entity": [
            "Age",
            "Alcohol",
            "Birth",
            "BP",
            "Cerebrovascular_Disease",
            "Contagious_Disease",
            "Cardiac_Disease",
            "Date",
            "Death",
            "Diabetes",
            "Diet",
            "Direction",
            "Discharge_Admission",
            "Drug_Form",
            "Drug_Ingredient",
            "Drug_Route",
            "Drug_Strength",
            "Duration",
            "Employment",
            "Ethnicity_Race",
            "External_Body_Part",
            "Frequency",
            "Gender",
            "Gestation",
            "Header_Family_History",
            "Header_Section",
            "Header_Social_History",
            "Hospital_Department",
            "Hyperlipidemia",
            "Hypertension",
            "Injury",
            "Internal_Organ_Biostructure",
            "Kidney_Disease",
            "Labor_Delivery",
            "Medical_Device",
            "Metastasis",
            "Modifier",
            "Obesity",
            "Oncological",
            "Overweight",
            "Procedure",
            "Psychological_Condition",
            "Puerperal",
            "Pulsation",
            "Relationship",
            "Relative_Date",
            "Respiration",
            "Sexual",
            "Smoking",
            "Substance",
            "Symptom",
            "Syndrome_Disorder_Disease",
            "Test",
            "Time",
            "Treatment",
            "Vaccine",
            "Vital_Signs_Finding",
            "Vital_Signs_Header",
            "Weight",
            "Header_Medical_History"
        ],
        "model_name": "nlp-health-ner-clinical-large-en"
    }
}

# %%
result = api_service.run_model(model_id, payload)

# %%
result
# Out:
# {'used_credits': 6.640000000000001,
#  'status': True,
#  'data_type': ['data_json'],
#  'output': {'data_json': {'result': [[{'entity': 'Age',
#       'confidence': 0.9985573291778564,
#       'chunk': '42-year-old',
#       'begin': 2,
#       'end': 13},
#      {'entity': 'Gender',
#       'confidence': 0.9997252821922302,
#       'chunk': 'woman',
#       'begin': 14,
#       'end': 19},
#      {'entity': 'Diabetes',
#       'confidence': 0.9871678054332733,
#       'chunk': 'type 1 diabetes',
#       'begin': 25,
#       'end': 40},
#      {'entity': 'Duration',
#       'confidence': 0.9966606497764587,
#       'chunk': 'for 22 years',
#       'begin': 41,
#       'end': 53},
#      {'entity': 'Relationship',
#       'confidence': 0.9819955825805664,
#       'chunk': 'married',
#       'begin': 58,
#       'end': 65},
#      {'entity': 'Gender',
#       'confidence': 0.9996737241744995,
#       'chunk': 'she',
#       'begin': 80,
#       'end': 83},
#      {'entity': 'Gender',
#       'confidence': 0.9989137649536133,
#       'chunk': 'her husband',
#       'begin': 88,
#       'end': 99},
#      {'entity': 'Gender',
#       'confidence': 0.999718964099884,
#       'chunk': 'woman',
#       'begin': 167,
#       'end': 172},
#      {'entity': 'Hypertension',
#       'confidence': 0.9950319528579712,
#       'chunk': 'hypertension',
#       'begin': 177,
#       'end': 189},
#      {'entity': 'Drug_Ingredient',
#       'confidence': 0.9973885416984558,
#       'chunk': 'diuretic',
#       'begin': 258,
#       'end': 266},
#      {'entity': 'BP',
#       'confidence': 0.6614670356114706,
#       'chunk': 'at 120/80',
#       'begin': 294,
#       'end': 303},
#      {'entity': 'Gender',
#       'confidence': 0.9991468191146851,
#       'chunk': 'Her',
#       'begin': 311,
#       'end': 314},
#      {'entity': 'Test',
#       'confidence': 0.999115526676178,
#       'chunk': 'glycated hemoglobin',
#       'begin': 315,
#       'end': 334},
#      {'entity': 'Test',
#       'confidence': 0.5249614119529724,
#       'chunk': 'HbA1c)',
#       'begin': 336,
#       'end': 342},
#      {'entity': 'Gender',
#       'confidence': 0.9995617270469666,
#       'chunk': 'Her',
#       'begin': 368,
#       'end': 371},
#      {'entity': 'Drug_Ingredient',
#       'confidence': 0.9972844123840332,
#       'chunk': 'insulin',
#       'begin': 372,
#       'end': 379},
#      {'entity': 'Drug_Ingredient',
#       'confidence': 0.9776312708854675,
#       'chunk': 'insulin',
#       'begin': 428,
#       'end': 435},
#      {'entity': 'Drug_Route',
#       'confidence': 0.7610291242599487,
#       'chunk': 'infusion',
#       'begin': 436,
#       'end': 444},
#      {'entity': 'Medical_Device',
#       'confidence': 0.28236615657806396,
#       'chunk': 'pump',
#       'begin': 445,
#       'end': 449},
#      {'entity': 'Drug_Ingredient',
#       'confidence': 0.989769458770752,
#       'chunk': 'insulin aspart',
#       'begin': 456,
#       'end': 470},
#      {'entity': 'Gender',
#       'confidence': 0.999516487121582,
#       'chunk': 'Her',
#       'begin': 472,
#       'end': 475},
#      {'entity': 'Weight',
#       'confidence': 0.9971046447753906,
#       'chunk': 'weight is 60 kgÍ¾',
#       'begin': 484,
#       'end': 501},
#      {'entity': 'Gender',
#       'confidence': 0.9991390705108643,
#       'chunk': 'her',
#       'begin': 508,
#       'end': 511},
#      {'entity': 'Drug_Ingredient',
#       'confidence': 0.9924017190933228,
#       'chunk': 'insulin',
#       'begin': 512,
#       'end': 519},
#      {'entity': 'Gender',
#       'confidence': 0.9887136816978455,
#       'chunk': 'her',
#       'begin': 560,
#       'end': 563},
#      {'entity': 'Weight',
#       'confidence': 0.8921363353729248,
#       'chunk': 'weight in kilograms',
#       'begin': 564,
#       'end': 583},
#      {'entity': 'Frequency',
#       'confidence': 0.9970250725746155,
#       'chunk': 'daily',
#       'begin': 595,
#       'end': 600},
#      {'entity': 'Gender',
#       'confidence': 0.9996727705001831,
#       'chunk': 'She',
#       'begin': 602,
#       'end': 605},
#      {'entity': 'Gender',
#       'confidence': 0.9996528625488281,
#       'chunk': 'she',
#       'begin': 620,
#       'end': 623},
#      {'entity': 'Gestation',
#       'confidence': 0.993739128112793,
#       'chunk': 'pregnant',
#       'begin': 644,
#       'end': 652},
#      {'entity': 'Relative_Date',
#       'confidence': 0.9705509543418884,
#       'chunk': 'next month',
#       'begin': 653,
#       'end': 663}]]}}}

# %% [markdown]
# #### Visualize the result

# %%
from aimped.nlp.ner import NERVisualizer
viz = NERVisualizer()

# %%
result = result["output"]["data_json"]["result"][0]

# %%
viz.display_visualization(text, result)
# Out:
#         <style>
#         .non-ner {
#             color: black;
#             line-height: 2.2rem;
#             font-size: 1rem;
#         }
#         .entity-wrapper {
#             display: inline-flex;
#             justify-content: space-between;
#             text-align: center;
#             border-radius: 5px;
#             margin: 3px 2px;
#             border: 1px solid;
#             overflow: hidden;
#             font-size: 1rem;
#         }
#         .entity-name {
#             font-size: 0.9rem;
#             line-height: 1.5rem;
#             text-align: center;
#             font-weight: 400;
#             padding: 2px 5px;
#             display: inline-block;
#         }
#         .entity-type {
#             font-size: 0.9rem;
#             line-height: 1.5rem;
#             color: #fff;
#             text-transform: uppercase;
#             font-weight: 500;
#             display: inline-block;
#             padding: 2px 5px;
#         }
#         </style>
#         <div style="padding: 14px;"><div dir="auto"><span class="non-ner">A </span>
#                 <span class="entity-wrapper" style="background-color: rgba(92, 92, 224, 0.12); border-color: #5C5CE0;">
#                     <span class="entity-name">42-year-old</span>
#                     <span class="entity-type" style="background-color: #5C5CE0;">Age</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">woman</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">Gender</span>
#                 </span>
#             <span class="non-ner"> with </span>
#                 <span class="entity-wrapper" style="background-color: rgba(206, 39, 131, 0.12); border-color: #CE2783;">
#                     <span class="entity-name">type 1 diabetes</span>
#                     <span class="entity-type" style="background-color: #CE2783;">Diabetes</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(210, 178, 0, 0.12); border-color: #D2B200;">
#                     <span class="entity-name">for 22 years</span>
#                     <span class="entity-type" style="background-color: #D2B200;">Duration</span>
#                 </span>
#             <span class="non-ner"> was </span>
#                 <span class="entity-wrapper" style="background-color: rgba(177, 48, 189, 0.12); border-color: #B130BD;">
#                     <span class="entity-name">married</span>
#                     <span class="entity-type" style="background-color: #B130BD;">Relationship</span>
#                 </span>
#             <span class="non-ner"> recently, and </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">she</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">Gender</span>
#                 </span>
#             <span class="non-ner"> and </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">her husband</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">Gender</span>
#                 </span>
#             <span class="non-ner"> have decided to have a child. Neither had children previously. The </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">woman</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">Gender</span>
#                 </span>
#             <span class="non-ner"> has </span>
#                 <span class="entity-wrapper" style="background-color: rgba(22, 135, 140, 0.02); border-color: #16878C;">
#                     <span class="entity-name">hypertension</span>
#                     <span class="entity-type" style="background-color: #16878C;">Hypertension</span>
#                 </span>
#             <span class="non-ner"> treated with an angiotensin-converting enzyme (ACE) inhibitor and a </span>
#                 <span class="entity-wrapper" style="background-color: rgba(124, 195, 63, 0.12); border-color: #7CC33F;">
#                     <span class="entity-name">diuretic</span>
#                     <span class="entity-type" style="background-color: #7CC33F;">Drug_Ingredient</span>
#                 </span>
#             <span class="non-ner"> to maintain blood pressure </span>
#                 <span class="entity-wrapper" style="background-color: rgba(134, 76, 204, 0.12); border-color: #864CCC;">
#                     <span class="entity-name">at 120/80</span>
#                     <span class="entity-type" style="background-color: #864CCC;">BP</span>
#                 </span>
#             <span class="non-ner"> mm Hg. </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">Her</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">Gender</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(20, 115, 230, 0.12); border-color: #1473E6;">
#                     <span class="entity-name">glycated hemoglobin</span>
#                     <span class="entity-type" style="background-color: #1473E6;">Test</span>
#                 </span>
#             <span class="non-ner"> (</span>
#                 <span class="entity-wrapper" style="background-color: rgba(20, 115, 230, 0.12); border-color: #1473E6;">
#                     <span class="entity-name">HbA1c)</span>
#                     <span class="entity-type" style="background-color: #1473E6;">Test</span>
#                 </span>
#             <span class="non-ner"> is 6.7% (normal, <5.7%). </span>
#                 <span class="entity-wrapper" style="background-color: rgba(61, 167, 78, 0.12); border-color: #3DA74E;">
#                     <span class="entity-name">Her</span>
#                     <span class="entity-type" style="background-color: #3DA74E;">Gender</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(124, 195, 63, 0.12); border-color: #7CC33F;">
#                     <span class="entity-name">insulin</span>
#                     <span class="entity-type" style="background-color: #7CC33F;">Drug_Ingredient</span>
#                 </span>
#             <span class="non-ner"> doses are all administered through a continuous </span>
#                 <span class="entity-wrapper" style="background-color: rgba(124, 195, 63, 0.12); border-color: #7CC33F;">
#                     <span class="entity-name">insulin</span>
#                     <span class="entity-type" style="background-color: #7CC33F;">Drug_Ingredient</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(215, 55, 63, 0.12); border-color: #D7373F;">
#                     <span class="entity-name">infusion</span>
#                     <span class="entity-type" style="background-color: #D7373F;">Drug_Route</span>
#                 </span>
#             <span class="non-ner"> </span>
#                 <span class="entity-wrapper" style="background-color: rgba(218, 123, 17, 0.12); border-color: #DA7B11;">
#                     <span class="entity-name">pump</span>
#                     <span class="entity-type" style="background-color: #DA7B11;">Medical_Device</span>
#                 </span>
#             <span class="non-ner"> using </span>
#                 <span class="entity-wrapper" style="background-color: rgba(124, 195, 63, 0.12); border-color: #7CC3
